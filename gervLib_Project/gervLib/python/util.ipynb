# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import cm
import matplotlib.patches as mpatches
import io
import seaborn as sns
import os
from os import listdir
from os.path import isfile, join
# %matplotlib inline
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["axes.titlesize"] = 12 
plt.rcParams["figure.figsize"] = (3,3)

# %%
#VP-TREE

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
df.at[18, "type"] = "Pivô"
circle1 = plt.Circle(xy=(0, 0), radius=11.67, color='black', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))
p1.add_patch(circle1)
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_vp.svg", dpi=300)

# %%
df.at[18, "type"] = "Pivô"

df.at[12, "type"] = "Pivô"
df.at[6, "type"] = "Pivô"

circle1 = plt.Circle(xy=(0, 0), radius=11.67, color='black', fill=False)

circle2 = plt.Circle(xy=(3, 5), radius=5.04, color='black', fill=False)
circle3 = plt.Circle(xy=(16, 19), radius=12.18, color='black', fill=False)

p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)

p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_vp.svg", dpi=300)

# %%
df.at[18, "type"] = "Pivô"

df.at[12, "type"] = "Pivô"
df.at[6, "type"] = "Pivô"

df.at[19, "type"] = "Pivô"
df.at[16, "type"] = "Pivô"
df.at[13, "type"] = "Pivô"
df.at[11, "type"] = "Pivô"


circle1 = plt.Circle(xy=(0, 0), radius=11.67, color='black', fill=False)

circle2 = plt.Circle(xy=(3, 5), radius=5.04, color='black', fill=False)
circle3 = plt.Circle(xy=(16, 19), radius=12.18, color='black', fill=False)

# circle4 = plt.Circle(xy=(4, 6), radius=1.41, color='black', fill=False)
# circle5 = plt.Circle(xy=(6, 0), radius=3.60, color='black', fill=False)
# circle6 = plt.Circle(xy=(13, 5), radius=4.12, color='black', fill=False)
# circle7 = plt.Circle(xy=(18, 19), radius=8.24, color='black', fill=False)




p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)

p1.add_patch(circle2)
p1.add_patch(circle3)

# p1.add_patch(circle4)
# p1.add_patch(circle5)
# p1.add_patch(circle6)
# p1.add_patch(circle7)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl3_vp.svg", dpi=300)

# %%
#MVP-TREE

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
df.at[8, "type"] = "Pivô"
circle1 = plt.Circle(xy=(7, 1), radius=7.51, color='orange', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))
p1.add_patch(circle1)
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_mvp.svg", dpi=300)

# %%
df.at[8, "type"] = "Pivô"

df.at[14, "type"] = "Pivô"

circle1 = plt.Circle(xy=(7, 1), radius=7.51, color='orange', fill=False)

circle2 = plt.Circle(xy=(1, 4), radius=6.40, color='purple', fill=False)
circle3 = plt.Circle(xy=(1, 4), radius=16.12, color='purple', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_mvp.svg", dpi=300)

# %%
df.at[8, "type"] = "Pivô"

df.at[14, "type"] = "Pivô"

df.at[17, "type"] = "Pivô"
df.at[12, "type"] = "Pivô"
df.at[10, "type"] = "Pivô"
df.at[0, "type"] = "Pivô"
df.at[3, "type"] = "Pivô"
df.at[11, "type"] = "Pivô"
df.at[1, "type"] = "Pivô"
df.at[6, "type"] = "Pivô"

circle1 = plt.Circle(xy=(7, 1), radius=7.51, color='orange', fill=False)

circle2 = plt.Circle(xy=(1, 4), radius=6.40, color='purple', fill=False)
circle3 = plt.Circle(xy=(1, 4), radius=16.12, color='purple', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl3_mvp.svg", dpi=300)

# %%
#OMNI

# %%
data = [[8.602325,10.000000],
[13.601471,16.031220],
[0.000000,5.830952],
[9.219544,9.219544],
[12.529964,14.035669],
[13.453624,13.000000],
[21.470911,19.104973],
[17.117243,12.041595],
[1.414214,5.656854],
[17.804494,18.027756],
[3.605551,5.385165],
[9.486833,7.211103],
[5.830952,0.000000],
[22.472205,20.518285],
[6.403124,2.236068],
[8.062258,5.000000],
[6.324555,5.099020],
[5.099020,2.000000],
[6.000000,5.830952],
[6.324555,1.414214]]

df = pd.DataFrame(data, columns=['D1', 'D2'])
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

plt.vlines(8.33, ymin = 0.0, ymax = 25.0, color="tab:red", linestyle='--')

plt.savefig("lvl1_omni.svg", dpi=300)

# %%
p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

plt.vlines(8.33, ymin = 0.0, ymax = 25.0, color="tab:red", linestyle='--')
plt.hlines(5.05, xmin = 0.0, xmax=8.33, color="tab:red", linestyle='--')
plt.hlines(13.52, xmin = 8.33, xmax=25, color="tab:red", linestyle='--')

plt.savefig("lvl2_omni.svg", dpi=300)

# %%
data = [[8.602325,10.000000],
[13.601471,16.031220],
[0.000000,5.830952],
[9.219544,9.219544],
[12.529964,14.035669],
[13.453624,13.000000],
[21.470911,19.104973],
[17.117243,12.041595],
[1.414214,5.656854],
[17.804494,18.027756],
[3.605551,5.385165],
[9.486833,7.211103],
[5.830952,0.000000],
[22.472205,20.518285],
[6.403124,2.236068],
[8.062258,5.000000],
[6.324555,5.099020],
[5.099020,2.000000],
[6.000000,5.830952],
[6.324555,1.414214],
[3.000000,3.605551]]

df = pd.DataFrame(data, columns=['D1', 'D2'])
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

df.at[20, "type"] = "Pivô"
df.at[10, "type"] = "Auxiliar"
df.at[17, "type"] = "Auxiliar"
df.at[8, "type"] = "Auxiliar"

p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

plt.vlines(8.33, ymin = 0.0, ymax = 25.0, color="tab:red", linestyle='--')
plt.hlines(5.05, xmin = 0.0, xmax=8.33, color="tab:red", linestyle='--')
plt.hlines(13.52, xmin = 8.33, xmax=25, color="tab:red", linestyle='--')

plt.savefig("query_pvt_space_omni.svg", dpi=300)

# %%
#PM

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
df.at[0, "type"] = "Pivô"

circle1 = plt.Circle(xy=(13, 5), radius=8.60, color='black', fill=False)


p1 = sns.scatterplot(data=df[0:5], x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))

p1.add_patch(circle1)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_pm.svg", dpi=300)

# %%
df.at[0, "type"] = "Instância"

df.at[1, "type"] = "Pivô"
df.at[5, "type"] = "Pivô"


circle1 = plt.Circle(xy=(19, 4), radius=20.66, color='black', fill=False)
circle2 = plt.Circle(xy=(19, 4), radius=2.83, color='black', fill=False)
circle3 = plt.Circle(xy=(15, 10), radius=13.45, color='black', fill=False)


p1 = sns.scatterplot(data=df[0:6], x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_pm.svg", dpi=300)

# %%
df.at[0, "type"] = "Instância"
df.at[1, "type"] = "Instância"
df.at[5, "type"] = "Instância"

df.at[1, "type"] = "Pivô"
df.at[12, "type"] = "Pivô"
df.at[19, "type"] = "Pivô"
df.at[2, "type"] = "Pivô"
df.at[5, "type"] = "Pivô"
df.at[0, "type"] = "Pivô"
df.at[3, "type"] = "Pivô"
df.at[11, "type"] = "Pivô"


circle1 = plt.Circle(xy=(19, 4), radius=22.73, color='black', fill=False)
circle2 = plt.Circle(xy=(19, 4), radius=2.83, color='black', fill=False)
circle3 = plt.Circle(xy=(3, 5), radius=5.83, color='black', fill=False)
circle4 = plt.Circle(xy=(4, 6), radius=4.0, color='black', fill=False)
circle5 = plt.Circle(xy=(15, 10), radius=15.52, color='black', fill=False)
circle6 = plt.Circle(xy=(13, 5), radius=7.21, color='black', fill=False)
circle7 = plt.Circle(xy=(15, 10), radius=9.49, color='black', fill=False)
circle8 = plt.Circle(xy=(9, 9), radius=9.43, color='black', fill=False)

p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)
p1.add_patch(circle4)
p1.add_patch(circle5)
p1.add_patch(circle6)
p1.add_patch(circle7)
p1.add_patch(circle8)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl3_pm.svg", dpi=300)
