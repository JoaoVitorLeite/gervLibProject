# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import cm
import matplotlib.patches as mpatches
import io
import seaborn as sns
import os
from os import listdir
from os.path import isfile, join
# %matplotlib inline
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["axes.titlesize"] = 12 
plt.rcParams["figure.figsize"] = (2.7,2.7)
plt.rcParams['patch.linewidth'] = 0.75

# %%
#VP-TREE

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
df.at[18, "type"] = "Pivô"
circle1 = plt.Circle(xy=(0, 0), radius=11.67, color='black', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))
p1.add_patch(circle1)
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_vp.svg", dpi=300)

# %%
df.at[18, "type"] = "Pivô"

df.at[12, "type"] = "Pivô"
df.at[6, "type"] = "Pivô"

circle1 = plt.Circle(xy=(0, 0), radius=11.67, color='black', fill=False)

circle2 = plt.Circle(xy=(3, 5), radius=5.04, color='black', fill=False)
circle3 = plt.Circle(xy=(16, 19), radius=12.18, color='black', fill=False)

p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)

p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_vp.svg", dpi=300)

# %%
df.at[18, "type"] = "Pivô"

df.at[12, "type"] = "Pivô"
df.at[6, "type"] = "Pivô"

df.at[19, "type"] = "Pivô"
df.at[16, "type"] = "Pivô"
df.at[13, "type"] = "Pivô"
df.at[11, "type"] = "Pivô"


circle1 = plt.Circle(xy=(0, 0), radius=11.67, color='black', fill=False)

circle2 = plt.Circle(xy=(3, 5), radius=5.04, color='black', fill=False)
circle3 = plt.Circle(xy=(16, 19), radius=12.18, color='black', fill=False)

# circle4 = plt.Circle(xy=(4, 6), radius=1.41, color='black', fill=False)
# circle5 = plt.Circle(xy=(6, 0), radius=3.60, color='black', fill=False)
# circle6 = plt.Circle(xy=(13, 5), radius=4.12, color='black', fill=False)
# circle7 = plt.Circle(xy=(18, 19), radius=8.24, color='black', fill=False)




p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)

p1.add_patch(circle2)
p1.add_patch(circle3)

# p1.add_patch(circle4)
# p1.add_patch(circle5)
# p1.add_patch(circle6)
# p1.add_patch(circle7)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl3_vp.svg", dpi=300)

# %%
#MVP-TREE

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
df.at[8, "type"] = "Pivô"
circle1 = plt.Circle(xy=(7, 1), radius=7.51, color='orange', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))
p1.add_patch(circle1)
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_mvp.svg", dpi=300)

# %%
df.at[8, "type"] = "Pivô"

df.at[14, "type"] = "Pivô"

circle1 = plt.Circle(xy=(7, 1), radius=7.51, color='orange', fill=False)

circle2 = plt.Circle(xy=(1, 4), radius=6.40, color='purple', fill=False)
circle3 = plt.Circle(xy=(1, 4), radius=16.12, color='purple', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_mvp.svg", dpi=300)

# %%
df.at[8, "type"] = "Pivô"

df.at[14, "type"] = "Pivô"

df.at[17, "type"] = "Pivô"
df.at[12, "type"] = "Pivô"
df.at[10, "type"] = "Pivô"
df.at[0, "type"] = "Pivô"
df.at[3, "type"] = "Pivô"
df.at[11, "type"] = "Pivô"
df.at[1, "type"] = "Pivô"
df.at[6, "type"] = "Pivô"

circle1 = plt.Circle(xy=(7, 1), radius=7.51, color='orange', fill=False)

circle2 = plt.Circle(xy=(1, 4), radius=6.40, color='purple', fill=False)
circle3 = plt.Circle(xy=(1, 4), radius=16.12, color='purple', fill=False)


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,21,10))
p1.set_xticklabels(np.arange(0,21,10))
p1.set(yticks=np.arange(0,21,10))
p1.set_yticklabels(np.arange(0,21,10))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl3_mvp.svg", dpi=300)

# %%
#OMNI

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl0_1_omni.svg", dpi=300)

# %%
data = [[8.602325,10.000000],
[13.601471,16.031220],
[0.000000,5.830952],
[9.219544,9.219544],
[12.529964,14.035669],
[13.453624,13.000000],
[21.470911,19.104973],
[17.117243,12.041595],
[1.414214,5.656854],
[17.804494,18.027756],
[3.605551,5.385165],
[9.486833,7.211103],
[5.830952,0.000000],
[22.472205,20.518285],
[6.403124,2.236068],
[8.062258,5.000000],
[6.324555,5.099020],
[5.099020,2.000000],
[6.000000,5.830952],
[6.324555,1.414214]]

df = pd.DataFrame(data, columns=['D1', 'D2'])
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

plt.vlines(8.33, ymin = 0.0, ymax = 25.0, color="tab:red", linestyle='--')
plt.hlines(5.05, xmin = 0.0, xmax = 25.0, color="black", linestyle='--')

plt.savefig("lvl1_omni.svg", dpi=300)

# %%
p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

plt.vlines(8.33, ymin = 0.0, ymax = 25.0, color="tab:red", linestyle='--')
plt.hlines(5.05, xmin = 0.0, xmax=8.33, color="tab:red", linestyle='--')
plt.hlines(13.52, xmin = 8.33, xmax=25, color="tab:red", linestyle='--')

plt.savefig("lvl2_omni.svg", dpi=300)

# %%
data = [[8.602325,10.000000],
[13.601471,16.031220],
[0.000000,5.830952],
[9.219544,9.219544],
[12.529964,14.035669],
[13.453624,13.000000],
[21.470911,19.104973],
[17.117243,12.041595],
[1.414214,5.656854],
[17.804494,18.027756],
[3.605551,5.385165],
[9.486833,7.211103],
[5.830952,0.000000],
[22.472205,20.518285],
[6.403124,2.236068],
[8.062258,5.000000],
[6.324555,5.099020],
[5.099020,2.000000],
[6.000000,5.830952],
[6.324555,1.414214],
[3.000000,3.605551]]

df = pd.DataFrame(data, columns=['D1', 'D2'])
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

df.at[20, "type"] = "Pivô"
df.at[10, "type"] = "Auxiliar"
df.at[17, "type"] = "Auxiliar"
df.at[8, "type"] = "Auxiliar"

p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

plt.vlines(8.33, ymin = 0.0, ymax = 25.0, color="tab:red", linestyle='--')
plt.hlines(5.05, xmin = 0.0, xmax=8.33, color="tab:red", linestyle='--')
plt.hlines(13.52, xmin = 8.33, xmax=25, color="tab:red", linestyle='--')

plt.savefig("query_pvt_space_omni.svg", dpi=300)

# %%
#PM

# %%
path = "../datasets/Dataset1.csv"
df = pd.read_csv(path, sep=' ', header=None)
df.columns = ["D1", "D2"]
df["type"] = "Instância"
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
df.at[0, "type"] = "Pivô"

# 'Nivel 1'
circle1 = plt.Circle(xy=(13, 5), radius=8.60, color='#7D1D3F', fill=False)
#

p1 = sns.scatterplot(data=df[0:5], x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))

p1.add_patch(circle1)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_pm.svg", dpi=300)

# %%
df.at[0, "type"] = "Instância"

df.at[1, "type"] = "Pivô"
df.at[5, "type"] = "Pivô"

# 'Nivel 1'
circle1 = plt.Circle(xy=(19, 4), radius=20.66, color='#7D1D3F', fill=False)
#

# 'Nivel 2'
circle2 = plt.Circle(xy=(19, 4), radius=2.83, color='#84714F', fill=False)
circle3 = plt.Circle(xy=(15, 10), radius=13.45, color='#84714F', fill=False)
#

p1 = sns.scatterplot(data=df[0:6], x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_pm.svg", dpi=300)

# %%
df.at[0, "type"] = "Instância"
df.at[1, "type"] = "Instância"
df.at[5, "type"] = "Instância"

df.at[1, "type"] = "Pivô"
df.at[12, "type"] = "Pivô"
df.at[19, "type"] = "Pivô"
df.at[2, "type"] = "Pivô"
df.at[5, "type"] = "Pivô"
df.at[0, "type"] = "Pivô"
df.at[3, "type"] = "Pivô"
df.at[11, "type"] = "Pivô"


# 'Nivel 1'
circle1 = plt.Circle(xy=(19, 4), radius=22.73, color='#7D1D3F', fill=False)
circle3 = plt.Circle(xy=(3, 5), radius=5.83, color='#7D1D3F', fill=False)
circle5 = plt.Circle(xy=(15, 10), radius=15.52, color='#7D1D3F', fill=False)
#

# 'Nivel 2'
circle2 = plt.Circle(xy=(19, 4), radius=2.83, color='#84714F', fill=False)
circle4 = plt.Circle(xy=(4, 6), radius=4.0, color='#84714F', fill=False)
circle7 = plt.Circle(xy=(15, 10), radius=9.49, color='#84714F', fill=False)
circle6 = plt.Circle(xy=(13, 5), radius=7.21, color='#84714F', fill=False)
circle8 = plt.Circle(xy=(9, 9), radius=9.43, color='#84714F', fill=False)
#


p1 = sns.scatterplot(data=df, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))

p1.add_patch(circle1)
p1.add_patch(circle2)
p1.add_patch(circle3)
p1.add_patch(circle4)
p1.add_patch(circle5)
p1.add_patch(circle6)
p1.add_patch(circle7)
p1.add_patch(circle8)

p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl3_pm.svg", dpi=300)

# %%
#SPB

# %%
path = "../datasets/Dataset1.csv"
dataset_original = pd.read_csv(path, sep=' ', header=None)
dataset_original.columns = ["D1", "D2"]
dataset_original["type"] = "Instância"

path2 = "./exemplo_fig_spb/bulk_load_pivot_mapping.txt"
pivot_mapping = pd.read_csv(path2, sep=' ', header=None)
pivot_mapping.drop(pivot_mapping.columns[[2]], axis=1, inplace=True)
pivot_mapping.columns = ["D1", "D2"]
pivot_mapping["type"] = "Instância"

path3 = './exemplo_fig_spb/bulk_load_disc.txt'
disc = pd.read_csv(path3, sep=' ', header=None)
disc.drop(disc.columns[[2]], axis=1, inplace=True)
disc.columns = ["D1", "D2"]
disc["type"] = "Instância"

custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

# %%
dataset_original.at[2, "type"] = "Pivô"
dataset_original.at[12, "type"] = "Pivô"

p1 = sns.scatterplot(data=dataset_original, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl1_spb.svg", dpi=300)

# %%
pivot_mapping.at[2, "type"] = "Pivô"
pivot_mapping.at[12, "type"] = "Pivô"

p1 = sns.scatterplot(data=pivot_mapping, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,26,5))
p1.set_xticklabels(np.arange(0,26,5))
p1.set(yticks=np.arange(0,26,5))
p1.set_yticklabels(np.arange(0,26,5))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)
plt.savefig("lvl2_spb.svg", dpi=300)

# %%
# disc.at[2, "type"] = "Pivô"
# disc.at[12, "type"] = "Pivô"
# disc = disc.sort_values("type")

# p1 = sns.scatterplot(data=disc, x="D1", y="D2", hue="type", palette=custom_palette)
# p1.set(xticks=np.arange(0,4,1))
# p1.set_xticklabels(np.arange(0,4,1))
# p1.set(yticks=np.arange(0,4,1))
# p1.set_yticklabels(np.arange(0,4,1))
# p1.set_aspect('equal')
# p1.legend().set_visible(False)
# p1.set(xlabel=None)
# p1.set(ylabel=None)
# plt.savefig("lvl3_spb.svg", dpi=300)

# %%
disc.at[2, "type"] = "Pivô"
disc.at[12, "type"] = "Pivô"
disc = disc.sort_values("type")

p1 = sns.scatterplot(data=disc, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,4,1))
p1.set_xticklabels(np.arange(0,4,1))
p1.set(yticks=np.arange(0,4,1))
p1.set_yticklabels(np.arange(0,4,1))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

lineColor = "tab:grey"
lineSTL = "-"
line_w = 0.75

plt.hlines(0, xmin = 0, xmax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(1, ymin = 0, ymax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(1, xmin = 0, xmax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(0, ymin = 1, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(3, xmin = 0, xmax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(1, ymin = 2, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(2, xmin = 1, xmax = 2, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(2, ymin = 2, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(3, xmin = 2, xmax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(3, ymin = 1, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(1, xmin = 2, xmax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(2, ymin = 0, ymax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(0, xmin = 2, xmax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)

plt.savefig("lvl3_spb.svg", dpi=300)

# %%
disc.at[2, "type"] = "Pivô"
disc.at[12, "type"] = "Pivô"
disc = disc.sort_values("type")

p1 = sns.scatterplot(data=disc, x="D1", y="D2", hue="type", palette=custom_palette, linewidth = 0)
p1.set(xticks=np.arange(0,4,1))
p1.set_xticklabels(np.arange(0,4,1))
p1.set(yticks=np.arange(0,4,1))
p1.set_yticklabels(np.arange(0,4,1))
p1.set_aspect('equal')
p1.legend().set_visible(False)
p1.set(xlabel=None)
p1.set(ylabel=None)

lineColor = "tab:grey"
lineSTL = "-"
line_w = 0.75

plt.hlines(0, xmin = 0, xmax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(1, ymin = 0, ymax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(1, xmin = 0, xmax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(0, ymin = 1, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(3, xmin = 0, xmax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(1, ymin = 2, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(2, xmin = 1, xmax = 2, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(2, ymin = 2, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(3, xmin = 2, xmax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(3, ymin = 1, ymax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(1, xmin = 2, xmax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.vlines(2, ymin = 0, ymax = 1, color = lineColor, linestyle = lineSTL, linewidth = line_w)
plt.hlines(0, xmin = 2, xmax = 3, color = lineColor, linestyle = lineSTL, linewidth = line_w)

rect1 = plt.Rectangle((0,0), 1, 1, fill = False, color = "tab:purple", linestyle = '--', linewidth = 1.5)
p1.add_patch(rect1)

rect2 = plt.Rectangle((0,1), 2, 1, fill = False, color = "tab:purple", linestyle = '--', linewidth = 1.5)
p1.add_patch(rect2)

rect3 = plt.Rectangle((2,2), 1, 1, fill = False, color = "tab:purple", linestyle = '--', linewidth = 1.5)
p1.add_patch(rect3)

rect4 = plt.Rectangle((2,1), 1, 2, fill = False, color = "tab:purple", linestyle = '--', linewidth = 1.5)
p1.add_patch(rect4)

plt.savefig("lvl4_spb.svg", dpi=300)

# %%
#BPP

# %%
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
    }

lst = [[1,2],
      [2,1],
      [2,2],
      [2,3],
      [3,1],
      [3,3],
      [4,2],
      [5,2]]

df = pd.DataFrame(lst, columns=["D1", "D2"])
df["type"] = "Instância"
df.at[1, "type"] = "Pivô"
df.at[3, "type"] = "Pivô"
df.at[7, "type"] = "Pivô"

plt.figure(figsize=(1.5,1.5))

g = sns.scatterplot(x="D1",
                    y="D2",
                    hue="type", data=df, palette=custom_palette, linewidth = 0, legend=None)
g.set(xticks=np.arange(0,7,1))
g.set(yticks=np.arange(0,5,1))
g.set(xlabel=None)
g.set(ylabel=None)
plt.savefig("bpp_aux.svg", dpi=300)

# %%
#Pivot_mapping
custom_palette = {
        'Instância': 'tab:blue',
        'Pivô': 'tab:red',
        'Auxiliar': 'tab:green'
}

lst = [[0,0],
      [1,1],
      [1,2],
      [2,0],
      [3,1],
      [4,2],
      [4,3],
      [5,1],
      [6,0]]

df = pd.DataFrame(lst, columns=["D1", "D2"])
df["type"] = "Instância"
df.at[0, "type"] = "Pivô"

df2 = pd.DataFrame([lst[4]], columns=["D1", "D2"])

def Euclidean_Dist(df1, df2, cols=['x_coord','y_coord']):
    return np.linalg.norm(df1[cols].values - df2[cols].values,
                   axis=1)

dist = Euclidean_Dist(df, df2, cols=["D1", "D2"])

print(dist)
print(np.sort(dist))
print(np.unique(np.sort(dist)))

# v = list(zip(dist, [0]*9))
# df3 = pd.DataFrame(v, columns=["D1", "D2"])
# df3["type"] = "Instância"
# df3.at[0, "type"] = "Pivô"

# fig = plt.figure(figsize=(3,3))

# g1 = sns.scatterplot(x="D1",
#                     y="D2",
#                     hue="type", data=df, palette=custom_palette, linewidth = 0, legend=None)
# g1.set(xticks=np.arange(0,7,1))
# g1.set(yticks=np.arange(0,4,1))
# g1.set(xlabel=None)
# g1.set(ylabel=None)
# plt.savefig("pivot_mapping_aux1.svg", dpi=300)

# fig = plt.figure(figsize=(3,3))
# g2 = sns.scatterplot(x="D1",
#                     y="D2",
#                     hue="type", data=df3, palette=custom_palette, linewidth = 0, legend=None)
# g2.set(xticks=np.arange(0,7,1))
# g2.set(xticks=np.arange(0,7,1))
# g2.set(yticks=np.arange(0,4,1))
# g2.set(xlabel=None)
# g2.set(ylabel=None)
# plt.savefig("pivot_mapping_aux2.svg", dpi=300)
# Out:
# [3.16227766 2.         2.23606798 1.41421356 0.         1.41421356
#  2.23606798 2.         3.16227766]
# [0.         1.41421356 1.41421356 2.         2.         2.23606798
#  2.23606798 3.16227766 3.16227766]
# [0.         1.41421356 2.         2.23606798 3.16227766]

# %%
#check duplicates pivots
def dup_pivots(path):
    onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
    for f in onlyfiles:
        df = pd.read_csv(join(path, f), sep=' ', header=None)
        duplicate = df[df.duplicated()]
        if duplicate.shape[0] != 0:
            print(join(path,f))
            
dup_pivots("../results/mnist_pivots/")
# Out:
# ../results/mnist_pivots/BPP_PIVOTS_VALUE_350.csv
# ../results/mnist_pivots/BPP_PIVOTS_ID_350.csv
# ../results/mnist_pivots/BPP_PIVOTS_VALUE_300.csv
# ../results/mnist_pivots/BPP_PIVOTS_ID_300.csv

# %%
df = pd.read_csv("../results/mnist_pivots/BPP_PIVOTS_ID_350.csv", sep=' ', header=None)
duplicate = df[df.duplicated()]
duplicate
# Out:
#          0
# 362  67325
# 374  55655
# 493  22491
# 626  51894
